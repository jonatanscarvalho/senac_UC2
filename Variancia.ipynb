# %%
import pandas as pd
import numpy as np

# %%
dados = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'

df = pd.read_csv(dados, encoding="latin1", sep= ';')
df
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 37583   159    3  2026  2026m03    35     4  Cachoeiras de Macacu  3300803
# 37584   165    3  2026  2026m03    33     5           Mangaratiba  3302601
# 37585   166    3  2026  2026m03    33     5        Angra dos Reis  3300100
# 37586   167    3  2026  2026m03    43     5                Paraty  3303807
# 37587   168    3  2026  2026m03    28     5             Rio Claro  3304409
#
# ...

# %%
array_roubo = df['roubo_veiculo']
array_furto = df['furto_veiculo']
array_rec = df['recuperacao_veiculo']

array_furto = np.array(df['furto_veiculo'])
array_roubo = np.array(df['roubo_veiculo'])
array_rec = np.array(df['recuperacao_veiculo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
#força de correlação entre furto e roubo de veiculos
#atividade 2
matriz_cov_furto_roubo = np.cov(array_furto, array_roubo)
matriz_cov_furto_roubo= matriz_cov_furto_roubo[0,1]

r1=np.corrcoef(array_furto, array_roubo)
correla_furto_roubo = r1[0,1]

# %%
df.describe()
# Out:
#                cisp           mes           ano          aisp          risp  \
# count  37588.000000  37588.000000  37588.000000  37588.000000  37588.000000
# mean      81.724513      6.453203   2014.274822     20.152708      3.869932
# std       48.320601      3.465985      6.677154     11.350589      2.011415
# min        1.000000      1.000000   2003.000000      1.000000      1.000000
# 25%       38.000000      3.000000   2009.000000     10.000000      2.000000
# 50%       78.000000      6.000000   2014.000000     20.000000      4.000000
# 75%      125.000000      9.000000   2020.000000     30.000000      6.000000
# max      168.000000     12.000000   2026.000000     43.000000      7.000000
#
#               mcirc    hom_doloso  lesao_corp_morte    latrocinio  \
# count  3.758800e+04  37588.000000      37588.000000  37588.000000
# mean   3.791586e+06      2.916383          0.028227      0.095190
# std    1.740552e+06      4.318591          0.180091      0.365578
# ...

# %%
df = pd.DataFrame(dados)
print(f"Variância: {np.var(df['nota']):.2f}")
print(f"Desvio Padrão: {np.std(df['nota']):.2f}")
cov = np.cov(df['nota'], df['horas'])[0, 1]
print(f"Covariância: {cov:.2f}")
r = np.corrcoef(df['nota'], df['horas'])[0, 1]
print(f"Pearson r: {r:.4f}")
print("Relação: MUITO FORTE POSITIVA!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.DataFrame(dados)
#       2 print(f"Variância: {np.var(df['nota']):.2f}")
#       3 print(f"Desvio Padrão: {np.std(df['nota']):.2f}")
#       4 cov = np.cov(df['nota'], df['horas'])[0, 1]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:869, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     865                 )
#     866         # For data is scalar
#     867         else:
#     868             if index is None or columns is None:
# --> 869                 raise ValueError("DataFrame constructor not properly called!")
#     870
#     871             index = ensure_index(index)
#     872             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
import numpy as np
import pandas as pd
dados = {
'aluno': ['Ana','Bruno','Carol','Diego',
'Elisa','Felipe','Gabi','Hugo'],
'nota': [8.5, 6.0, 9.2, 5.5, 7.8, 4.0, 9.0, 6.5],
'horas': [6, 3, 8, 2, 5, 1, 7, 4 ]}

# %%
df = pd.DataFrame(dados)
print(f"Variância: {np.var(df['nota']):.2f}")
print(f"Desvio Padrão: {np.std(df['nota']):.2f}")
cov = np.cov(df['nota'], df['horas'])[0, 1]
print(f"Covariância: {cov:.2f}")
r = np.corrcoef(df['nota'], df['horas'])[0, 1]
print(f"Pearson r: {r:.4f}")
print("Relação: MUITO FORTE POSITIVA!")
# Out:
# Variância: 3.02
# Desvio Padrão: 1.74
# Covariância: 4.48
# Pearson r: 0.9834
# Relação: MUITO FORTE POSITIVA!

# %%
# Desvio padrão das notas
desvio = np.std(df['nota'])
print(f"Desvio Padrão: {desvio:.2f}")
# Saída: Desvio Padrão: 1.74
# Interpretando com a média
media = np.mean(df['nota'])
print(f"Média das notas: {media:.2f}")
faixa_inf = media - desvio
faixa_sup = media 
print(f"Faixa típica: {media-desvio:.2f} até {media+desvio:.2f}")
# Saída:
# Média das notas: 7.06
# Faixa típica: 5.32 até 8.80
# Out:
# Desvio Padrão: 1.74
# Média das notas: 7.06
# Faixa típica: 5.32 até 8.80

# %%
matriz_cov = np.cov(df['nota'], df['horas'])
print(matriz_cov)
# [[3.46  4.48]
#  [4.48  6.00]]
# Extraindo só o valor da covariância
    # [ 0 , 1 ] linhas e colunas 
cov_valor = matriz_cov[0, 1]
print(f"Covariância: {cov_valor:.2f}")
# Saída: Covariância: 4.48
# Forma alternativa com Pandas
print(df[['nota','horas']].cov())
#         nota    horas
# nota   3.456   4.479
# horas  4.479   6.000
# Out:
# [[3.45696429 4.47857143]
#  [4.47857143 6.        ]]
# Covariância: 4.48
#            nota     horas
# nota   3.456964  4.478571
# horas  4.478571  6.000000

# %%
# Forma 1 — Pandas (mais usada na prática)
corr_pandas = df[['nota','horas']].corr()
print(corr_pandas)
#           nota     horas
# nota   1.0000    0.9749
# horas  0.9749    1.0000
# Forma 2 — NumPy
r = np.corrcoef(df['nota'], df['horas'])
print(f"Pearson r = {r[0,1]:.4f}")
# Saída: Pearson r = 0.9749
# Interpretação:
# r = 0.97 → correlação MUITO FORTE positiva
# Confirma: mais horas de estudo = nota maior!
# Out:
#            nota     horas
# nota   1.000000  0.983369
# horas  0.983369  1.000000
# Pearson r = 0.9834
