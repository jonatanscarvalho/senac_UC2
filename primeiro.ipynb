# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('pedidos_narashop.csv',sep=';')
df
# Out:
#        pedido_id           vendedor         categoria  \
# 0          10001    Rafael Oliveira          Esportes
# 1          10002       Leandro Reis       Eletrônicos
# 2          10003     Flávia Azevedo       Eletrônicos
# 3          10004      Lucas Ribeiro          Esportes
# 4          10005     Vinícius Lopes       Eletrônicos
# ...          ...                ...               ...
# 19995      29996      Tatiane Cunha          Esportes
# 19996      29997           Ana Lima  Casa e Decoração
# 19997      29998     Patrícia Rocha       Eletrônicos
# 19998      29999  Alexandre Lacerda          Esportes
# 19999      30000      Thiago Santos  Casa e Decoração
#
#                        produto status_pedido  quantidade  valor_unitario  \
# 0      Raquete de Beach Tennis      Entregue           5           98.01
# 1                  SSD Externo      Entregue           4          599.89
# 2                     Notebook      Entregue           5         3774.96
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_entregue_acima_500 = df.loc[(df['status_pedido' ]=='entregue')&(df['valor_pedido'] >500 )]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_produto = df.groupby('produto')['valor_pedido'].sum().reset_index()
df_produto.sort_values(by='valor_pedido', ascending=False, inplace=True)
df_produto.head(3)

# %%
array_valor_produto = np.array(df_produto['valor_pedido'])
q1= np.percentille(array_valor_produto, 25)
q3= np.percentille(array_valor_produto, 75)

# %%
df_produto_25_mais= df_produto.loc[df_produto['valor_pedido'] > q3]
df_produto_25_mais

# %%
df_produto_25_menos= df_produto.loc[df_produto['valor_pedido'] < q1]
df_produto_25_menos

# %%
# Out:
#   Cell In[10], line 3
#     = [45000, 28000, 19000, 31000]
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![{294F4956-8F26-4CCB-91EC-CEBEB1A5FA20}.png](attachment:{294F4956-8F26-4CCB-91EC-CEBEB1A5FA20}.png)

# %%
df_vendedores = df.groupby('vendedores')['valor_pedido'].sum().reset_index()
df_vendedores.sort_values(by='valor_pedido', ascending=False, inplace=True)
df_vendedores.head(3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
array_valor_pedido=np.array(df['valor_pedido'])
media = np.mean(array_valor_pedido)
mediana = np.median(array_valor_pedido)
distancia = (media - mediana) / mediana

print(f'A media é de {media} \nA meduana é de {mediana}')
print(f'A distância entre a média e a mediana é de {distancia:.2%}')

# %%
categorias = ['Eletrônicos', 'Esportes', 'Brinquedos', 'Casa']
valores
= [45000, 28000, 19000, 31000]
plt.bar(categorias, valores)
plt.title('Faturamento por Categoria — NaraShop')
plt.show()
# Out:
#   Cell In[8], line 3
#     = [45000, 28000, 19000, 31000]
#     ^
# SyntaxError: invalid syntax
