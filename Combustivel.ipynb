# %%
import pandas as pd
import numpy as np
import matplotlib_inline as plt

# %%
df_2024_01 = pd.read_csv('dados combustivel\Preços semestrais - AUTOMOTIVOS_2024.01.csv',sep=';', decimal=',')
df_2024_02 = pd.read_csv('dados combustivel\Preços semestrais - AUTOMOTIVOS_2024.02.csv',sep=';', decimal=',')
df_2025_01 = pd.read_csv('dados combustivel\Preços semestrais - AUTOMOTIVOS_2025.01.csv',sep=';', decimal=',')
df_2025_02 = pd.read_csv('dados combustivel\Preços semestrais - AUTOMOTIVOS_2025.02.csv',sep=';', decimal=',')

df = pd.concat([df_2024_01, df_2024_02,
                df_2025_01, df_2025_02],
               ignore_index=True)

print(df.shape); display(df.head())
df.head(5)
# Out:
# C:\Users\jonatans.carvalho\AppData\Local\Temp\ipykernel_17912\4076918591.py:3: DtypeWarning: Columns (0: Regiao - Sigla, 1: Estado - Sigla, 2: Municipio, 3: Revenda, 4: CNPJ da Revenda, 5: Nome da Rua, 6: Numero Rua, 7: Complemento, 8: Bairro, 9: Cep, 10: Produto, 11: Data da Coleta, 12: Unidade de Medida, 13: Bandeira) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2025_01 = pd.read_csv('dados combustivel\Preços semestrais - AUTOMOTIVOS_2025.01.csv',sep=';', decimal=',')
# (1712267, 16)
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             NE             AL  ARAPIRACA
# 1             NE             AL  ARAPIRACA
# 2             NE             AL  ARAPIRACA
# 3             NE             AL  ARAPIRACA
# 4             NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# ...

# %%
# exercicio 2
df_gas_rj = df.loc[(df['Estadi - sigla'] == 'RJ') & (df['Produto'] == 'GASOLINA')]

# %%
#depois ele agrupou
#exercicio 2
df_munic_rj_gas = df_gas_rj.groupby('Municipio')['Valor de Venda'].mean().reset_index()

df_munic_rj_gas.sort_values(by='Valor de Venda', ascending=False)
inplace=True

df_munic_rj_gas

# %%
#exercicio 3
df_posto_rj = df_gas_rj.groupby('Revenda')['Valor de Venda'].mean().reset_index()
df_posto_rj.sort_values(by='Valor de Venda', ascending=False,inplace=True)
df_posto_rj

# %%
#outliers
array_posto = np.arry(df_posto_rj['Valor de Venda'])
minimo = np.min (array_posto)
maximo = np.max (array_posto)

# %%
### Um gráfico revela em segundos o que levaria minutos.

# %%
#.loc para os outlayers
df_outlier_posto_rj = df_posto_rj.loc[df_posto_rj['Valor de Venda']]

# %%
#4 exercico   .isin cria lista de dados
df_rj_sp_etanol = df.loc[(df['Etanol -Sigla'].isin('RJ','SP'))] &

# %%
df_munic_rj = df.loc[(df['Municipio']== 'RIO DE JANEIRO') & (df['Produto'] == 'GASOLINA')]
df_munic_rj.head(3)

# %%
#resposta 4
#filtra primeiro depois agrupa 
df_bairro_rj = df_munic_rj.groupby('Bairro')['Valor de Venda'].mean().reset_index()

df_bairro_rj.sort_values(by='Valor de Venda', ascendind=False),inplace=True

df_bairro_rj
